# %% [markdown]
# ### Shift Operator:
# The shift operator creates a new neighbour by moving the position of a job in an engineer’s schedule to another position on the same schedule. The target position for the moved job is selected greedily where the total time taken to complete the schedule is the least. It has a complexity of O(n2).
#
# The output of test is printed out at the end of the notebook.

# %%
#Importing necessary libraries
import re
import time
import warnings
import numpy as np
import pandas as pd
import math
import requests
import json
import geocoder as gc
import sys
import os
from geopy import distance 
from geopy.geocoders import Nominatim

#Inputs
st = time.time()
sst = time.process_time()
E = ["DY11 5SW","WV4 6ED","B79 7PB","B90 8AT","B46 1AN","B98 9EY","B96 6BD","WV7 3BW","CV9 1LQ","DY11 5SW"]
J = "B16 9HN"

#Routing engine
def osrm_route(jobs): 
    lat = []
    long = []
    print(jobs)
    for i in range(len(jobs)):
        locator = Nominatim(user_agent="myGeocoder")
        location = locator.geocode(jobs[i])
        lat.append(location.latitude)
        long.append(location.longitude)
    json_data = []
    lurl = ""
    for i in range(len(jobs)):
        lurl += f'{long[i]},{lat[i]};'
    url = 'http://127.0.0.1:5000/route/v1/driving/'
    url += lurl[:-1]
    r = requests.get(url)
    json_data.append(r.json())
    if ("routes" not in json_data[0]):
        return -1
    return json_data[0]['routes'][0]['duration']

#Function to calculate time of schedule
def calculate_time(arr):
    travel_time = osrm_route(arr)
    if (travel_time == -1):
        print("Route not Possible")  
        return -1
    travel_time = travel_time/60
    return travel_time

print("Intial Order: \n")
print(E)
print("\n")
stime = 100000000
for j in range(len(E)+1):
    arr = []
    for k in range(len(E)):
        if(k==j):
            arr.append(J)
        arr.append(E[k])
    if(len(E) == len(arr)):
        arr.append(J)
    xtime = calculate_time(arr)
    print("Total Time Required : {} \n".format(xtime))
    if(xtime < stime):
        stime = xtime
        x = []
        for l in arr:
            x.append(l)
            
print("Best Schedule:")
print(x)
print("\nTotal Time Required for Schedule: {} minutes".format(stime))
et = time.time()
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')
eet = time.process_time()
res = eet - sst
print('CPU Execution time:', res, 'seconds')
# Out:
# Intial Order:
#
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW']
#
#
# ['B16 9HN', 'DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW']
# Total Time Required : 351.9916666666667
#
# ['DY11 5SW', 'B16 9HN', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW']
# Total Time Required : 345.7933333333333
#
# ['DY11 5SW', 'WV4 6ED', 'B16 9HN', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW']
# Total Time Required : 335.39666666666665
#
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B16 9HN', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW']
# Total Time Required : 351.80333333333334
#
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B16 9HN', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW']
# Total Time Required : 353.14666666666665
#
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B16 9HN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW']
# Total Time Required : 343.77333333333337
#
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B16 9HN', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW']
# Total Time Required : 368.7366666666667
#
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'B16 9HN', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW']
# Total Time Required : 329.2133333333333
#
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'B16 9HN', 'CV9 1LQ', 'DY11 5SW']
# Total Time Required : 338.04
#
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'B16 9HN', 'DY11 5SW']
# Total Time Required : 321.9583333333333
#
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'DY11 5SW', 'B16 9HN']
# Total Time Required : 352.40333333333336
#
# Best Schedule:
# ['DY11 5SW', 'WV4 6ED', 'B79 7PB', 'B90 8AT', 'B46 1AN', 'B98 9EY', 'B96 6BD', 'WV7 3BW', 'CV9 1LQ', 'B16 9HN', 'DY11 5SW']
#
# Total Time Required for Schedule: 321.9583333333333 minutes
# Execution time: 60.40881943702698 seconds
# CPU Execution time: 2.828125 seconds
